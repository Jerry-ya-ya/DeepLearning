# %% [markdown]
# ## 安裝 kaggle 套件（Colab 預設可能沒裝）

# %%
# !pip install -q kaggle

# %% [markdown]
# ## 1. 掛載Google雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. 請先依照以下步驟，下載kaggle.json檔案到自己的電腦

# %% [markdown]
# ### 建立 kaggle.json API 金鑰流程
# 	1.	前往 https://www.kaggle.com 登入帳號。
# 	2.	點擊右上角個人頭像 → Setting。
# 	3.	向下捲到 API 區塊 → 點選「Create New Token」。
# 	4.	會下載一個 kaggle.json 檔案，內含您的 username 與 key。

# %% [markdown]
# ## 3. 在 Colab 中上傳並設定金鑰

# %%
# 上傳 kaggle.json
from google.colab import files
files.upload()  # 會跳出上傳視窗，選取剛剛的 kaggle.json

# 建立資料夾並移動金鑰
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json  # 設定權限
# Out:
#      <input type="file" id="files-01af88e7-d35f-48b0-9a14-7d1ac0f45e98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01af88e7-d35f-48b0-9a14-7d1ac0f45e98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 4. 下載資料集（以 Clouds Photos 為例）
#
# ex: 找到的Kaggle 找到該資料集的 URL為 https://www.kaggle.com/datasets/jockeroika/clouds-photos
#
# 則資料集名稱為 jockeroika/clouds-photos

# %%
# !kaggle datasets download -d fareselmenshawii/human-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fareselmenshawii/human-dataset
# License(s): CC0-1.0
# ...
# 100% 5.33G/5.33G [00:57<00:00, 99.7MB/s]

# %% [markdown]
# ### 下載並解壓資料集(若更換資料集, 請自行修改資料集名稱)
# * 請自行修改壓縮檔的檔名(xxx.zip)
# * 請修改要解壓縮的目標資料夾(可填入Google雲端硬碟的絕對路徑)

# %%
# !unzip -q human-dataset.zip -d /content/drive/MyDrive/Colab/human-dataset
